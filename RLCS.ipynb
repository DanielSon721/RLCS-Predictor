# %%
import pandas as pd

# %%
matches = pd.read_csv("matches_by_teams.csv")

# %%
#variable types
matches.dtypes
# Out:
# match_id                               object
# color                                  object
# team_id                                object
# team_slug                              object
# team_name                              object
# team_region                            object
# core_shots                            float64
# core_goals                            float64
# core_saves                            float64
# core_assists                          float64
# core_score                            float64
# core_shooting_percentage              float64
# boost_bpm                             float64
# boost_bcpm                            float64
# boost_avg_amount                      float64
# boost_amount_collected                float64
# boost_amount_stolen                   float64
# boost_amount_collected_big            float64
# boost_amount_stolen_big               float64
# boost_amount_collected_small          float64
# boost_amount_stolen_small             float64
# boost_count_collected_big             float64
# boost_count_stolen_big                float64
# boost_count_collected_small           float64
# boost_count_stolen_small              float64
# boost_amount_overfill                 float64
# boost_amount_overfill_stolen          float64
# boost_amount_used_while_supersonic    float64
# boost_time_zero_boost                 float64
# boost_time_full_boost                 float64
# boost_time_boost_0_25                 float64
# boost_time_boost_25_50                float64
# boost_time_boost_50_75                float64
# boost_time_boost_75_100               float64
# movement_total_distance               float64
# movement_time_supersonic_speed        float64
# movement_time_boost_speed             float64
# movement_time_slow_speed              float64
# movement_time_ground                  float64
# movement_time_low_air                 float64
# movement_time_high_air                float64
# movement_time_powerslide              float64
# movement_count_powerslide             float64
# positioning_time_defensive_third      float64
# positioning_time_neutral_third        float64
# positioning_time_offensive_third      float64
# positioning_time_defensive_half       float64
# positioning_time_offensive_half       float64
# positioning_time_behind_ball          float64
# positioning_time_in_front_ball        float64
# demo_inflicted                        float64
# demo_taken                            float64
# score                                 float64
# winner                                   bool
# dtype: object

# %%
matches["color_code"] = matches["color"].astype("category").cat.codes

# %%
matches["region_code"] = matches["team_region"].astype("category").cat.codes

# %%
matches["target"] = (matches["winner"] == True).astype("int")

# %%
matches
# Out:
#                        match_id   color                   team_id  \
# 0      6159ad3d143c37878b2384a9    blue  6020bc8ef1e4807cc700391a
# 1      6159ad3d143c37878b2384a9  orange  614c8930f8090ec745286474
# 2      6159ad3d143c37878b2384aa    blue  6020bc70f1e4807cc70023fb
# 3      6159ad3d143c37878b2384aa  orange  6156d4db143c37878b238367
# 4      6159ad3d143c37878b2384ab    blue  6020bc8ef1e4807cc7003915
# ...                         ...     ...                       ...
# 10589  62e02371da9d7ca1c7bb2f61  orange  6020bd98f1e4807cc700dc74
# 10590  62e02371da9d7ca1c7bb2f62    blue  6020bc70f1e4807cc70023a5
# 10591  62e02371da9d7ca1c7bb2f62  orange  605aca6853a71a78eacbc155
# 10592  62e02371da9d7ca1c7bb2f63    blue  6020bd98f1e4807cc700dc74
# 10593  62e02371da9d7ca1c7bb2f63  orange  6020bc70f1e4807cc70023a5
#
#                                              team_slug           team_name  \
# 0      https://octane.gg/teams/391a-ground-zero-gaming  GROUND ZERO GAMING
# 1           https://octane.gg/teams/6474-ranga-roundup       RANGA ROUNDUP
# 2               https://octane.gg/teams/23fb-renegades           RENEGADES
# 3         https://octane.gg/teams/8367-trident-esports     TRIDENT ESPORTS
# 4             https://octane.gg/teams/3915-dire-wolves         DIRE WOLVES
# ...                                                ...                 ...
# 10589            https://octane.gg/teams/dc74-team-bds            TEAM BDS
# 10590          https://octane.gg/teams/23a5-g2-esports          G2 ESPORTS
# 10591           https://octane.gg/teams/c155-faze-clan           FAZE CLAN
# 10592            https://octane.gg/teams/dc74-team-bds            TEAM BDS
# 10593          https://octane.gg/teams/23a5-g2-esports          G2 ESPORTS
#
#          team_region  core_shots  core_goals  core_saves  core_assists  ...  \
# 0            Oceania        34.0         9.0         8.0           7.0  ...
# 1            Oceania        15.0         5.0        21.0           3.0  ...
# 2            Oceania        46.0        21.0        10.0          21.0  ...
# 3            Oceania        16.0         4.0        16.0           3.0  ...
# 4            Oceania        46.0        12.0        13.0           9.0  ...
# ...              ...         ...         ...         ...           ...  ...
# 10589         Europe        61.0        18.0        29.0          14.0  ...
# 10590  North America        46.0        14.0        38.0          12.0  ...
# 10591  North America        50.0         5.0        26.0           4.0  ...
# 10592         Europe        36.0        10.0        19.0           8.0  ...
# 10593  North America        33.0         5.0        21.0           4.0  ...
#
#        positioning_time_offensive_half  positioning_time_behind_ball  \
# 0                              1237.05                       2339.78
# 1                               998.99                       2318.26
# 2                              1505.61                       2616.06
# 3                               859.84                       2355.02
# 4                              1718.97                       3444.64
# ...                                ...                           ...
# 10589                          2630.25                       5280.76
# 10590                          2162.11                       4417.79
# 10591                          2281.36                       4300.44
# 10592                          1685.25                       3816.52
# 10593                          2034.62                       3517.24
#
#        positioning_time_in_front_ball  demo_inflicted  demo_taken  score  \
# 0                              865.27             6.0         7.0    3.0
# 1                              890.30             7.0         6.0    0.0
# 2                              862.25            11.0         7.0    3.0
# 3                             1105.02             7.0        11.0    0.0
# 4                             1174.96            13.0         8.0    3.0
# ...                               ...             ...         ...    ...
# 10589                         1550.99            19.0        13.0    4.0
# 10590                         1616.17            22.0        15.0    4.0
# 10591                         1712.41            15.0        22.0    2.0
# 10592                         1227.65            11.0        21.0    4.0
# 10593                         1553.67            21.0        11.0    1.0
#
#        winner  color_code  region_code  target
# 0        True           0            5       1
# 1       False           1            5       0
# 2        True           0            5       1
# 3       False           1            5       0
# 4        True           0            5       1
# ...       ...         ...          ...     ...
# 10589    True           1            2       1
# 10590    True           0            4       1
# 10591   False           1            4       0
# 10592    True           0            2       1
# 10593   False           1            4       0
#
# [10594 rows x 57 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
train = matches[matches["match_id"] < '62a3988cda9d7ca1c7bb22ba']

# %%
test = matches[matches["match_id"] > '62a3988cda9d7ca1c7bb22ba']

# %%
predictors = ["color_code", "region_code", "core_shots", "core_shooting_percentage", "core_saves", "demo_inflicted"]

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
acc = accuracy_score(test["target"], preds)

# %%
acc
# Out:
# 0.8021978021978022

# %%
combined = pd.DataFrame(dict(actual=test["target"], prediction = preds))

# %%
pd.crosstab(index=combined["actual"], columns=combined["prediction"])
# Out:
# prediction   0   1
# actual
# 0           72  19
# 1           17  74

# %%
from sklearn.metrics import precision_score

# %%
precision_score(test["target"], preds)
# Out:
# np.float64(0.7956989247311828)

# %%
grouped_matches = matches.groupby("team_name")

# %%
group = grouped_matches.get_group("TEAM BDS")

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("match_id")
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
cols = ["core_shots", "core_saves", "core_goals", "core_score", "core_shooting_percentage", "movement_time_supersonic_speed", "demo_inflicted"]
new_cols = [f"{c}_rolling" for c in cols]

# %%
new_cols
# Out:
# ['core_shots_rolling',
#  'core_saves_rolling',
#  'core_goals_rolling',
#  'core_score_rolling',
#  'core_shooting_percentage_rolling',
#  'movement_time_supersonic_speed_rolling',
#  'demo_inflicted_rolling']

# %%
rolling_averages(group, cols, new_cols)
# Out:
#                        match_id   color                   team_id  \
# 972    61671750143c37878b238eab    blue  6020bd98f1e4807cc700dc74
# 2180   618005c6f8090ec74528a42a    blue  6020bd98f1e4807cc700dc74
# 2200   618005c6f8090ec74528a434    blue  6020bd98f1e4807cc700dc74
# 2213   618005c6f8090ec74528a43a  orange  6020bd98f1e4807cc700dc74
# 2326   618005e5f8090ec74528a44a    blue  6020bd98f1e4807cc700dc74
# ...                         ...     ...                       ...
# 10544  62e02350da9d7ca1c7bb2f4b    blue  6020bd98f1e4807cc700dc74
# 10550  62e02350da9d7ca1c7bb2f4e    blue  6020bd98f1e4807cc700dc74
# 10582  62e02371da9d7ca1c7bb2f5e    blue  6020bd98f1e4807cc700dc74
# 10589  62e02371da9d7ca1c7bb2f61  orange  6020bd98f1e4807cc700dc74
# 10592  62e02371da9d7ca1c7bb2f63    blue  6020bd98f1e4807cc700dc74
#
#                                    team_slug team_name team_region  \
# 972    https://octane.gg/teams/dc74-team-bds  TEAM BDS      Europe
# 2180   https://octane.gg/teams/dc74-team-bds  TEAM BDS      Europe
# 2200   https://octane.gg/teams/dc74-team-bds  TEAM BDS      Europe
# 2213   https://octane.gg/teams/dc74-team-bds  TEAM BDS      Europe
# 2326   https://octane.gg/teams/dc74-team-bds  TEAM BDS      Europe
# ...                                      ...       ...         ...
# 10544  https://octane.gg/teams/dc74-team-bds  TEAM BDS      Europe
# 10550  https://octane.gg/teams/dc74-team-bds  TEAM BDS      Europe
# 10582  https://octane.gg/teams/dc74-team-bds  TEAM BDS      Europe
# 10589  https://octane.gg/teams/dc74-team-bds  TEAM BDS      Europe
# 10592  https://octane.gg/teams/dc74-team-bds  TEAM BDS      Europe
#
#        core_shots  core_goals  core_saves  core_assists  ...  color_code  \
# 972          24.0         9.0        15.0           9.0  ...           0
# 2180         30.0         8.0        11.0           5.0  ...           0
# 2200         20.0         4.0        16.0           4.0  ...           0
# 2213         27.0         6.0        18.0           4.0  ...           1
# 2326         56.0        12.0        22.0          10.0  ...           0
# ...           ...         ...         ...           ...  ...         ...
# 10544        38.0        11.0        25.0           8.0  ...           0
# 10550        42.0        12.0        20.0           9.0  ...           0
# 10582        54.0        15.0        28.0          14.0  ...           0
# 10589        61.0        18.0        29.0          14.0  ...           1
# 10592        36.0        10.0        19.0           8.0  ...           0
#
#        region_code  target  core_shots_rolling  core_saves_rolling  \
# 972              2       1           54.000000           26.000000
# 2180             2       1           44.666667           23.000000
# 2200             2       1           39.000000           18.000000
# 2213             2       1           24.666667           14.000000
# 2326             2       1           25.666667           15.000000
# ...            ...     ...                 ...                 ...
# 10544            2       1           37.333333           17.666667
# 10550            2       1           30.000000           16.666667
# 10582            2       1           33.666667           19.333333
# 10589            2       1           44.666667           24.333333
# 10592            2       1           52.333333           25.666667
#
#        core_goals_rolling  core_score_rolling  \
# 972             10.000000         6264.333333
# 2180            10.333333         5505.333333
# 2200             9.333333         4927.000000
# 2213             7.000000         3704.333333
# 2326             6.000000         3638.666667
# ...                   ...                 ...
# 10544            8.000000         4487.333333
# 10550            6.333333         3824.666667
# 10582            9.000000         4540.666667
# 10589           12.666667         6123.333333
# 10592           15.000000         6870.333333
#
#        core_shooting_percentage_rolling  \
# 972                           18.749729
# 2180                          26.121524
# 2200                          27.208995
# 2213                          28.055556
# 2326                          22.962963
# ...                                 ...
# 10544                         19.539171
# 10550                         20.299404
# 10582                         25.522139
# 10589                         28.432192
# 10592                         28.619134
#
#        movement_time_supersonic_speed_rolling  demo_inflicted_rolling
# 972                                795.106667               19.000000
# 2180                               601.606667               18.666667
# 2200                               568.766667               17.333333
# 2213                               447.196667               13.333333
# 2326                               483.940000               12.000000
# ...                                       ...                     ...
# 10544                              796.820000               16.333333
# 10550                              603.890000               12.666667
# 10582                              639.263333               13.333333
# 10589                              886.033333               17.666667
# 10592                              989.396667               19.000000
#
# [67 rows x 64 columns]

# %%
matches_rolling = matches.groupby("team_name").apply(lambda x: rolling_averages(x, cols, new_cols))
# Out:
# /var/folders/zk/fp_x9fxd5bvc0s0t65kzck_m0000gq/T/ipykernel_13028/3985352770.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   matches_rolling = matches.groupby("team_name").apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
matches_rolling = matches_rolling.droplevel('team_name')

# %%
matches_rolling.index = range(matches_rolling.shape[0])

# %%
matches_rolling
# Out:
#                       match_id   color                   team_id  \
# 0     628357d7da9d7ca1c7baf0ca  orange  628355d1da9d7ca1c7baf0b0
# 1     628cdc02da9d7ca1c7bb0b84  orange  628355d1da9d7ca1c7baf0b0
# 2     628cdc02da9d7ca1c7bb0b8b  orange  628355d1da9d7ca1c7baf0b0
# 3     628cdc02da9d7ca1c7bb0b99    blue  628355d1da9d7ca1c7baf0b0
# 4     61606299f8090ec74528700d    blue  613b735bf8090ec7452851a8
# ...                        ...     ...                       ...
# 6446  616061f2f8090ec745286fdf  orange  61606469143c37878b2387b7
# 6447  61685f4af8090ec7452878a2    blue  61606469143c37878b2387b7
# 6448  61741c6c143c37878b23a766    blue  61606469143c37878b2387b7
# 6449  61741c6c143c37878b23a76b  orange  61606469143c37878b2387b7
# 6450  6183e19c143c37878b23c4a7    blue  61606469143c37878b2387b7
#
#                                    team_slug  team_name  \
# 0           https://octane.gg/teams/f0b0-966       +966
# 1           https://octane.gg/teams/f0b0-966       +966
# 2           https://octane.gg/teams/f0b0-966       +966
# 3           https://octane.gg/teams/f0b0-966       +966
# 4     https://octane.gg/teams/51a8-00-nation  00 NATION
# ...                                      ...        ...
# 6446      https://octane.gg/teams/87b7-zntra      ZNTRA
# 6447      https://octane.gg/teams/87b7-zntra      ZNTRA
# 6448      https://octane.gg/teams/87b7-zntra      ZNTRA
# 6449      https://octane.gg/teams/87b7-zntra      ZNTRA
# 6450      https://octane.gg/teams/87b7-zntra      ZNTRA
#
#                      team_region  core_shots  core_goals  core_saves  \
# 0     Middle East & North Africa        32.0         7.0        30.0
# 1     Middle East & North Africa        33.0         7.0        20.0
# 2     Middle East & North Africa        24.0         8.0         9.0
# 3     Middle East & North Africa        43.0         6.0        15.0
# 4                         Europe         NaN         NaN         NaN
# ...                          ...         ...         ...         ...
# 6446          Asia-Pacific South        27.0        10.0         9.0
# 6447          Asia-Pacific South        33.0        10.0        25.0
# 6448          Asia-Pacific South        36.0        12.0        14.0
# 6449          Asia-Pacific South         NaN         NaN         NaN
# 6450          Asia-Pacific South         NaN         NaN         NaN
#
#       core_assists  ...  color_code  region_code  target  core_shots_rolling  \
# 0              4.0  ...           1            3       0           37.333333
# 1              5.0  ...           1            3       1           33.666667
# 2              6.0  ...           1            3       0           38.000000
# 3              4.0  ...           0            3       0           29.666667
# 4              NaN  ...           0            2       1           30.000000
# ...            ...  ...         ...          ...     ...                 ...
# 6446           7.0  ...           1            1       1           36.000000
# 6447           8.0  ...           0            1       0           35.333333
# 6448           9.0  ...           0            1       1           32.000000
# 6449           NaN  ...           1            1       0           32.000000
# 6450           NaN  ...           0            1       0           40.666667
#
#       core_saves_rolling  core_goals_rolling  core_score_rolling  \
# 0              23.666667            8.666667         5079.000000
# 1              25.666667            7.333333         5030.333333
# 2              26.333333            7.000000         4951.666667
# 3              19.666667            7.333333         4080.000000
# 4              23.333333            7.000000         4968.666667
# ...                  ...                 ...                 ...
# 6446           22.666667           11.666667         5019.333333
# 6447           15.000000           12.333333         4400.000000
# 6448           19.000000           11.000000         4754.000000
# 6449           16.000000           10.666667         4489.666667
# 6450           27.666667           12.666667         6079.666667
#
#       core_shooting_percentage_rolling  \
# 0                            26.622370
# 1                            25.386905
# 2                            19.124278
# 3                            25.473485
# 4                            23.174603
# ...                                ...
# 6446                         32.085153
# 6447                         35.235429
# 6448                         34.483726
# 6449                         33.557800
# 6450                         30.743740
#
#       movement_time_supersonic_speed_rolling  demo_inflicted_rolling
# 0                                 844.733333               12.000000
# 1                                 828.536667               15.000000
# 2                                 820.930000               14.666667
# 3                                 727.933333               11.333333
# 4                                 744.696667               19.000000
# ...                                      ...                     ...
# 6446                              670.913333                8.000000
# 6447                              598.856667                7.000000
# 6448                              753.663333                6.666667
# 6449                              737.786667                8.666667
# 6450                             1068.500000               14.666667
#
# [6451 rows x 64 columns]

# %%
def make_predictions(data, predictors):
    train = data[data["match_id"] < '62a3988cda9d7ca1c7bb22ba']
    test = data[data["match_id"] > '62a3988cda9d7ca1c7bb22ba']
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], prediction = preds), index = test.index)
    precision = precision_score(test["target"], preds)
    return combined, precision

# %%
combined, precision = make_predictions(matches_rolling, predictors + new_cols)

# %%
precision
# Out:
# np.float64(0.7553191489361702)

# %%
combined
# Out:
#       actual  prediction
# 74         0           1
# 75         1           1
# 76         0           0
# 77         1           1
# 78         0           0
# ...      ...         ...
# 6062       1           1
# 6063       1           0
# 6064       0           0
# 6065       1           0
# 6066       0           0
#
# [176 rows x 2 columns]

# %%
combined = combined.merge(matches_rolling[["match_id", "team_name", "winner"]], left_index = True, right_index = True)

# %%
combined
# Out:
#       actual  prediction                  match_id   team_name  winner
# 74         0           1  62e022abc437fde7e02da87a  01 ESPORTS   False
# 75         1           1  62e022abc437fde7e02da883  01 ESPORTS    True
# 76         0           0  62e022abc437fde7e02da88a  01 ESPORTS   False
# 77         1           1  62e022abc437fde7e02da892  01 ESPORTS    True
# 78         0           0  62e022abc437fde7e02da895  01 ESPORTS   False
# ...      ...         ...                       ...         ...     ...
# 6062       1           1  62e022abc437fde7e02da890    VERSION1    True
# 6063       1           0  62e02350da9d7ca1c7bb2f4c    VERSION1    True
# 6064       0           0  62e02350da9d7ca1c7bb2f4e    VERSION1   False
# 6065       1           0  62e02350da9d7ca1c7bb2f51    VERSION1    True
# 6066       0           0  62e02371da9d7ca1c7bb2f60    VERSION1   False
#
# [176 rows x 5 columns]

# %%
merged = combined.merge(combined, left_on=["match_id"], right_on=["match_id"])

# %%
merged
# Out:
#      actual_x  prediction_x                  match_id team_name_x  winner_x  \
# 0           0             1  62e022abc437fde7e02da87a  01 ESPORTS     False
# 1           0             1  62e022abc437fde7e02da87a  01 ESPORTS     False
# 2           1             1  62e022abc437fde7e02da883  01 ESPORTS      True
# 3           1             1  62e022abc437fde7e02da883  01 ESPORTS      True
# 4           0             0  62e022abc437fde7e02da88a  01 ESPORTS     False
# ..        ...           ...                       ...         ...       ...
# 341         0             0  62e02350da9d7ca1c7bb2f4e    VERSION1     False
# 342         1             0  62e02350da9d7ca1c7bb2f51    VERSION1      True
# 343         1             0  62e02350da9d7ca1c7bb2f51    VERSION1      True
# 344         0             0  62e02371da9d7ca1c7bb2f60    VERSION1     False
# 345         0             0  62e02371da9d7ca1c7bb2f60    VERSION1     False
#
#      actual_y  prediction_y          team_name_y  winner_y
# 0           0             1           01 ESPORTS     False
# 1           1             1         KARMINE CORP      True
# 2           1             1           01 ESPORTS      True
# 3           0             0    GAIMIN GLADIATORS     False
# 4           0             0           01 ESPORTS     False
# ..        ...           ...                  ...       ...
# 341         0             0             VERSION1     False
# 342         0             0  SPACESTATION GAMING     False
# 343         1             0             VERSION1      True
# 344         1             1            FAZE CLAN      True
# 345         0             0             VERSION1     False
#
# [346 rows x 9 columns]

# %%
# Remove rows where team is versing themselves
merged.drop_duplicates(subset=['team_name_x', 'team_name_y'], inplace=True)

# %%
merged.index = range(merged.shape[0])

# %%
merged
# Out:
#      actual_x  prediction_x                  match_id team_name_x  winner_x  \
# 0           0             1  62e022abc437fde7e02da87a  01 ESPORTS     False
# 1           0             1  62e022abc437fde7e02da87a  01 ESPORTS     False
# 2           1             1  62e022abc437fde7e02da883  01 ESPORTS      True
# 3           0             0  62e022abc437fde7e02da88a  01 ESPORTS     False
# 4           1             1  62e022abc437fde7e02da892  01 ESPORTS      True
# ..        ...           ...                       ...         ...       ...
# 173         1             0  62e022abc437fde7e02da888    VERSION1      True
# 174         1             1  62e022abc437fde7e02da890    VERSION1      True
# 175         1             0  62e02350da9d7ca1c7bb2f4c    VERSION1      True
# 176         0             0  62e02350da9d7ca1c7bb2f4e    VERSION1     False
# 177         0             0  62e02371da9d7ca1c7bb2f60    VERSION1     False
#
#      actual_y  prediction_y        team_name_y  winner_y
# 0           0             1         01 ESPORTS     False
# 1           1             1       KARMINE CORP      True
# 2           0             0  GAIMIN GLADIATORS     False
# 3           1             1           DIGNITAS      True
# 4           0             0    SENBEI STRIKERS     False
# ..        ...           ...                ...       ...
# 173         0             0     VELOCE ESPORTS     False
# 174         0             0           THE CLUB     False
# 175         0             0        NRG ESPORTS     False
# 176         1             1           TEAM BDS      True
# 177         1             1          FAZE CLAN      True
#
# [178 rows x 9 columns]

# %%
merged[(merged["prediction_x"] == 1) & (merged["prediction_y"] == 0)]["actual_x"].value_counts()
# Out:
# actual_x
# 1    45
# 0     4
# Name: count, dtype: int64

# %%
45/49
# Out:
# 0.9183673469387755
